# %%
# from pyspark import pipelines as dp

sourceName = 'awk'
sourcePath = '/Volumes/declarativepipeline/landing'
fileFormat = 'parquet'
fileName = ['AdventureWorks_Organization','AdventureWorks_Scenario','AdventureWorks_account','AdventureWorks_Finance']
tabelSchema = 'bronze'


def getData(fileFormat: str, sourcePath: str, sourceName: str, fileName: str):
    """ 
    
    This function is used to read the data from the source path and return the dataframe.
    
    Parameters:
        fileFormat (str): The file format of the data.
        sourcePath (str): The path of the source.
        sourceName (str): The name of the source.
        fileName (str): The name of the file.
        
    Returns:
        dataframe: The dataframe of the data."""
    print(f'{sourcePath}/{sourceName}/{fileName}_*.{fileFormat}')
    # return (spark.readStream
    #             .format('cloudFiles')
    #             .option('cloudFiles.format',fileFormat)
    #             .load(f'{sourcePath}/{sourceName}/{fileName}_*.{fileFormat}')
    #         )

for table in fileName:
    print(table)
    # @dp.table(
    #     name = f'{tabelSchema}.{table}'  ,
    #     comment = f"{tabelSchema}.{table} Table Created for Source {sourceName}/{table}"     
    # )
    getData(fileFormat, sourcePath, sourceName,table)
