-- %%
INSERT INTO myproject_dev.etlconfig.source
SELECT uuid(), 'AdventureWorks','awk','SQL Server Database Storing Information About Finance Data', current_timestamp(), current_timestamp(), current_user(), current_user();

INSERT INTO myproject_dev.etlconfig.sourcetables
  SELECT uuid(), '8d7746dc-af75-4468-ac03-b582d6bee5b4', 'finance', 'Table Includes Financial Transactions', 'myproject', 'bronze', 'AdventureWorks_Finance', '/Volumes/myproject_dev/landing','parquet',NULL, current_timestamp(), current_timestamp(), current_user(), current_user()
UNION ALL
  SELECT uuid(), '8d7746dc-af75-4468-ac03-b582d6bee5b4', 'organization', 'Table Includes Organization Details. It''s a reference data', 'myproject', 'bronze', 'AdventureWorks_Organization', '/Volumes/myproject_dev/landing','parquet',NULL, current_timestamp(), current_timestamp(), current_user(), current_user()
UNION ALL
  SELECT uuid(), '8d7746dc-af75-4468-ac03-b582d6bee5b4', 'scenario', 'Table Includes Scenario Details', 'myproject', 'bronze', 'AdventureWorks_Scenario', '/Volumes/myproject_dev/landing', 'parquet',NULL,current_timestamp(), current_timestamp(), current_user(), current_user()
UNION ALL
  SELECT uuid(), '8d7746dc-af75-4468-ac03-b582d6bee5b4', 'account', 'Table Includes Account Details', 'myproject', 'bronze', 'AdventureWorks_account', '/Volumes/myproject_dev/landing','parquet',NULL, current_timestamp(), current_timestamp(), current_user(), current_user()
